# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Bank Client Data

# %%
df = pd.read_csv(r"C:\Users\zaida\Downloads\bank.csv",delimiter=";")

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# ### Missing Values Analysis

# %%
missing_values = df.isnull().sum()

print("Missing Values:")
print(missing_values)

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# There is no missing value in this dataset
# Out:
# Missing Values:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ### Visualization

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# "y" is my Target varible
df["y"].value_counts().plot(kind="bar")
# and it is an binary classification problem
# Out:
# <Axes: xlabel='y'>

# %%
# pie Diagram with percentage for variable job
df.job.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %%
# pie Diagram with percentage for variable maritial
df.marital.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %%
# pie Diagram with percentage for variable education
df.education.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### distribution of the categorical features with target variable "y"

# %%
categorical_features = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']

for feature in categorical_features:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=feature, data=df, hue='y')
    plt.xticks(rotation='vertical')
    plt.title(f'Distribution of {feature} with respect to Target Variable (y)')
    plt.show()

# %% [markdown]
# ### Encoding

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
# Using LabelEncoder in my target variable
label = LabelEncoder().fit_transform(df["y"])

# %%
label
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
df["y"] = label

# %%
df["y"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int32

# %%
df.marital.replace({'married':3, 'single':2, 'divorced':1, 'unknown':0},inplace=True)
df.default.replace({'no':1, 'unknown':0, 'yes':2},inplace=True)
df.housing.replace({'no':1, 'yes':2, 'unknown':0},inplace=True)
df.loan.replace({'no':1, 'yes':2, 'unknown':0},inplace=True)
df.contact.replace({'telephone':0, 'cellular':1},inplace=True)
df.month.replace({'may':5, 'jun':6, 'jul':7, 'aug':8, 'oct':10, 'nov':11, 'dec':12, 'mar':3, 'apr':4,  'sep':9},inplace=True)
df.day_of_week.replace({'mon':1, 'tue':2, 'wed':3, 'thu':4, 'fri':5},inplace=True)
df.poutcome.replace({'nonexistent':0, 'failure':1, 'success':2},inplace=True)
df.y.replace({'no':0, 'yes':1},inplace=True)

# %%
# Identify categorical columns that need label encoding
categorical_columns = df.select_dtypes(include='object').columns

# Apply label encoding to categorical columns
label_encoder = LabelEncoder()
df[categorical_columns] = df[categorical_columns].apply(lambda x: label_encoder.fit_transform(x.astype(str)))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  int32
#  2   marital         41188 non-null  int64
#  3   education       41188 non-null  int32
#  4   default         41188 non-null  int64
#  5   housing         41188 non-null  int64
#  6   loan            41188 non-null  int64
#  7   contact         41188 non-null  int64
#  8   month           41188 non-null  int64
#  9   day_of_week     41188 non-null  int64
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  int64
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        3          0        1        1     1        0      5
# 1   57    7        3          3        0        1     1        0      5
# 2   37    7        3          3        1        2     1        0      5
# 3   40    0        3          1        1        1     1        0      5
# 4   56    7        3          3        1        1     2        0      5
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         0           1.1
# 1            1  ...         1    999         0         0           1.1
# 2            1  ...         1    999         0         0           1.1
# 3            1  ...         1    999         0         0           1.1
# 4            1  ...         1    999         0         0           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %% [markdown]
# ### Selectiong Important Features Based On Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
abc=df_train[df_train.y==1]
df_train=pd.concat([df_train,abc,abc])

# %%
df_train_x = df_train.drop(columns=['y'])
df_train_y = df_train['y']

df_test_x = df_test.drop(columns=['y'])
df_test_y = df_test['y']

# %%
df.shape
# Out:
# (41188, 21)

# %%
rfc = RandomForestClassifier(class_weight='balanced',random_state=42,criterion='entropy', n_estimators= 125)

# %%
rfc.fit(df_train_x, df_train_y)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        n_estimators=125, random_state=42)

# %%
rfc.score(df_train_x, df_train_y)
# Out:
# 1.0

# %%
rfc.score(df_test_x,df_test_y)
# Out:
# 0.9110220927409566

# %% [markdown]
# ### Imbalencing

# %%
df.y.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='y'>

# %%
df.y.value_counts()
# Out:
# y
# 0    36548
# 1     4640
# Name: count, dtype: int64

# %%
Zero = df[df["y"] == 0]

# %%
One = df[df["y"] == 1]

# %%
Zero.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        3          0        1        1     1        0      5
# 1   57    7        3          3        0        1     1        0      5
# 2   37    7        3          3        1        2     1        0      5
# 3   40    0        3          1        1        1     1        0      5
# 4   56    7        3          3        1        1     2        0      5
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         0           1.1
# 1            1  ...         1    999         0         0           1.1
# 2            1  ...         1    999         0         0           1.1
# 3            1  ...         1    999         0         0           1.1
# 4            1  ...         1    999         0         0           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
One.head()
# Out:
#      age  job  marital  education  default  housing  loan  contact  month  \
# 75    41    1        1          0        0        2     1        0      5
# 83    49    2        3          6        0        2     1        0      5
# 88    49    9        3          2        1        1     1        0      5
# 129   41    9        3          5        0        2     1        0      5
# 139   45    1        3          2        0        2     1        0      5
#
#      day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 75             1  ...         1    999         0         0           1.1
# 83             1  ...         1    999         0         0           1.1
# 88             1  ...         1    999         0         0           1.1
# 129            1  ...         1    999         0         0           1.1
# 139            1  ...         1    999         0         0           1.1
#
#      cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
zero = Zero.sample(5000)

# %%
newdf = pd.concat([zero,One])

# %%
newdf.head()
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 39798   20    9        2          5        1        2     1        0      6
# 37484   36    0        3          6        1        1     1        1      8
# 33227   37    0        3          6        1        2     2        1      5
# 13746   29    2        3          5        1        1     1        1      7
# 30642   59   11        3          7        1        2     1        1      5
#
#        day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 39798            2  ...         1    999         1         1          -1.7
# 37484            4  ...         2    999         1         1          -2.9
# 33227            2  ...         1    999         1         1          -1.8
# 13746            4  ...         1    999         0         0           1.4
# 30642            1  ...         7      6         1         2          -1.8
#
# ...

# %% [markdown]
# ### Spliting

# %%
X = df.drop("y",axis=1)

# %%
y = df["y"]

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.20)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Random Forest

# %%
from sklearn.metrics import confusion_matrix,recall_score,precision_score,f1_score,accuracy_score,roc_curve,roc_auc_score

# %%
pred_test_df = rfc.predict(Xtest)
pred_train_df = rfc.predict(Xtrain)

# %%
tab_test_df=confusion_matrix(ytest,pred_test_df)
tab_test_df
# Out:
# array([[7219,   79],
#        [  68,  872]], dtype=int64)

# %%
tab_test_df.diagonal().sum()/tab_test_df.sum() * 100
# Out:
# 98.21558630735615

# %%
tab_train_df=confusion_matrix(ytrain,pred_train_df)
tab_train_df
# Out:
# array([[28922,   328],
#        [  258,  3442]], dtype=int64)

# %%
tab_train_df.diagonal().sum()/tab_train_df.sum() * 100
# Out:
# 98.22154779969651

# %%
acc=tab_test_df.diagonal().sum()/tab_test_df.sum()
tpr=recall_score(df_test_y,pred_test_df)
pre=precision_score(df_test_y,pred_test_df)
f1=f1_score(df_test_y,pred_test_df)
fpr=tab_test_df[0][1] / (tab_test_df[0][0] + tab_test_df[0][1])

print('acc is :', acc, '\n', 'tpr is :', tpr,'\n', 'pre is :', pre, '\n', 'f1 score is :',f1, '\n', 'fpr is:', fpr)
# Out:
# acc is : 0.9821558630735615
#  tpr is : 0.11229946524064172
#  pre is : 0.11041009463722397
#  f1 score is : 0.11134676564156946
#  fpr is: 0.010824883529734174

# %%
feature_importances = rfc.feature_importances_

# %%
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Display the top N important features (adjust N as needed)
top_n = 10
print(f'Top {top_n} Important Features:')
print(feature_importance_df.head(top_n))
# Visualize feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'][:top_n], feature_importance_df['Importance'][:top_n])
plt.xlabel('Importance')
plt.title('Top Features based on Random Forest Importance')
plt.show()
# Out:
# Top 10 Important Features:
#           Feature  Importance
# 10       duration    0.391899
# 18      euribor3m    0.097584
# 19    nr.employed    0.068933
# 0             age    0.067158
# 15   emp.var.rate    0.049221
# 1             job    0.035296
# 11       campaign    0.034795
# 3       education    0.033396
# 17  cons.conf.idx    0.033335
# 9     day_of_week    0.030095

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
search_dict_rfc={"criterion":["gini","entropy"],
              
              "n_estimators":(50,75,100,125)}

# %%
rfc_GridSearchCV = GridSearchCV(rfc,param_grid=search_dict_rfc)

# %%
rfc_GridSearchCV.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced',
#                                               criterion='entropy',
#                                               n_estimators=125,
#                                               random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': (50, 75, 100, 125)})

# %%
rfc_GridSearchCV.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 75}

# %%
rfc_GridSearchCV.best_score_
# Out:
# 0.9147192716236722

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(Xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
# Testing Score
lr.score(Xtest,ytest)
# Out:
# 0.9059237679048313

# %%
pred_test_df = lr.predict(Xtest)
pred_train_df = lr.predict(Xtrain)

# %%
tab_test_df=confusion_matrix(ytest,pred_test_df)
tab_test_df
# Out:
# array([[7085,  213],
#        [ 562,  378]], dtype=int64)

# %%
tab_test_df.diagonal().sum()/tab_test_df.sum() * 100
# Out:
# 90.59237679048313

# %%
precision_score(ytest,pred_test_df) *100
# Out:
# 63.95939086294417

# %%
f1_score(ytest,pred_test_df)
# Out:
# 0.4937949052906597

# %%
pred_prob=lr.predict_proba(Xtest)

# %%
roc_auc_score(ytest,pred_prob[: , 1])
# Out:
# 0.9219327067165006

# %%
fpr,tpr,thre=roc_curve(ytest,lr.predict_proba(Xtest)[:,1])

# %%
plt.plot(fpr,tpr)
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('Auroc on bank data')
plt.grid()
plt.text(x=.5,y=.5,s='Area is 0.92667')
# Out:
# Text(0.5, 0.5, 'Area is 0.92667')

# %%
acc=tab_test_df.diagonal().sum()/tab_test_df.sum()
tpr=recall_score(df_test_y,pred_test_df)
pre=precision_score(df_test_y,pred_test_df)
f1=f1_score(df_test_y,pred_test_df)
fpr=tab_test_df[0][1] / (tab_test_df[0][0] + tab_test_df[0][1])

print('acc is :', acc, '\n', 'tpr is :', tpr,'\n', 'pre is :', pre, '\n', 'f1 score is :',f1, '\n', 'fpr is:', fpr)
# Out:
# acc is : 0.9059237679048313
#  tpr is : 0.0748663101604278
#  pre is : 0.11844331641285956
#  f1 score is : 0.09174311926605502
#  fpr is: 0.02918607837763771

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import train_test_split
pb_train, pb_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
# abc=pb_train[pb_train.y==1]
# df_train=pd.concat([pb_train,abc,abc,abc,abc,abc])
# df_train.y.value_counts()

# %%
pb_train_x = pb_train.drop(columns=['y'])
pb_train_y = pb_train['y']

pb_test_x = pb_test.drop(columns=['y'])
pb_test_y = pb_test['y']

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion= 'gini', max_depth= 9, min_samples_split= 25,class_weight='balanced')

# %%
dt.fit(pb_train_x,pb_train_y)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=9,
#                        min_samples_split=25)

# %%
pred_dt_test=dt.predict(pb_test_x)

# %%
tab_dt=confusion_matrix(pb_test_y,pred_dt_test)
tab_dt
# Out:
# array([[6194, 1109],
#        [ 113,  822]], dtype=int64)

# %%
acc=tab_dt.diagonal().sum()/tab_dt.sum()
tpr=recall_score(pb_test_y,pred_dt_test)
pre=precision_score(pb_test_y,pred_dt_test)
f1=f1_score(pb_test_y,pred_dt_test)
fpr=tab_dt[0][1] / (tab_dt[0][0] + tab_dt[0][1])

print('acc is :', acc, '\n', 'tpr is :', tpr,'\n', 'pre is :', pre, '\n', 'f1 score is :',f1, '\n', 'fpr is:', fpr)
# Out:
# acc is : 0.8516630250060694
#  tpr is : 0.879144385026738
#  pre is : 0.42568617296737443
#  f1 score is : 0.5736217725052338
#  fpr is: 0.1518554018896344

# %%
dt.feature_importances_
# Out:
# array([0.01700468, 0.00174837, 0.        , 0.00596198, 0.00756464,
#        0.00071933, 0.00050561, 0.00235641, 0.09190805, 0.00571863,
#        0.49836837, 0.00598773, 0.00697414, 0.00181036, 0.00240565,
#        0.0052968 , 0.02086889, 0.00414686, 0.03977949, 0.28087402])

# %%
pb_train_x.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
feat_imp= pd.DataFrame()
feat_imp['Feat']=pb_train_x.columns
feat_imp['Imp']=dt.feature_importances_
feat_imp.sort_values('Imp',ascending=False)
# Out:
#               Feat       Imp
# 10        duration  0.498368
# 19     nr.employed  0.280874
# 8            month  0.091908
# 18       euribor3m  0.039779
# 16  cons.price.idx  0.020869
# 0              age  0.017005
# 4          default  0.007565
# 12           pdays  0.006974
# 11        campaign  0.005988
# 3        education  0.005962
# 9      day_of_week  0.005719
# 15    emp.var.rate  0.005297
# 17   cons.conf.idx  0.004147
# 14        poutcome  0.002406
# 7          contact  0.002356
# 13        previous  0.001810
# 1              job  0.001748
# 5          housing  0.000719
# 6             loan  0.000506
# 2          marital  0.000000

# %%
search_dict_dt={"criterion":["gini","entropy"],
              "max_depth":range(6,10),
              "min_samples_split":(25,50,75)}

# %%
dt_GridSearchCV = GridSearchCV(dt,param_grid=search_dict_dt)

# %%
dt_GridSearchCV.fit(pb_train_x,pb_train_y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(class_weight='balanced',
#                                               max_depth=9,
#                                               min_samples_split=25),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(6, 10),
#                          'min_samples_split': (25, 50, 75)})

# %%
dt_GridSearchCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 25}

# %%
dt_GridSearchCV.best_score_
# Out:
# 0.8541729893778452

# %%
# Calculating Performance

# %%
metrics_data = {
    'Model': ['Random Forest', 'Logistic Regression', 'Decision Tree'],
    'Accuracy': [0.9832, 0.9094, 0.8514],
    'True Positive Rate (Recall)': [0.1155, 0.0716, 0.8780],
    'Precision': [0.1171, 0.1124, 0.4251],
    'F1 Score': [0.1163, 0.0875, 0.5729],
    'False Positive Rate': [0.00943, 0.0287, 0.1519]
}

metrics_df = pd.DataFrame(metrics_data)
print(metrics_df)
# Out:
#                  Model  Accuracy  True Positive Rate (Recall)  Precision  \
# 0        Random Forest    0.9832                       0.1155     0.1171
# 1  Logistic Regression    0.9094                       0.0716     0.1124
# 2        Decision Tree    0.8514                       0.8780     0.4251
#
#    F1 Score  False Positive Rate
# 0    0.1163              0.00943
# 1    0.0875              0.02870
# 2    0.5729              0.15190

# %%
# Accuracy: Random Forest has the highest accuracy, but accuracy alone may not be the best metric for imbalanced datasets.

# True Positive Rate (Recall): Decision Tree has the highest recall, indicating that it captures a higher proportion of actual positive cases.

# Precision: Logistic Regression has the highest precision, indicating a lower rate of false positives.

# F1 Score: It balances precision and recall. Decision Tree has the highest F1 score.

# False Positive Rate: Logistic Regression has the lowest false positive rate.
